# %% [markdown]
# Vaccum Cleaning Agent with locations A and B

# %% [markdown]
# ![vc.png](attachment:vc.png)

# %% [markdown]
# # Some important things:
#
# 1. Agent Description: The aim of the agent .....
# 2. List the sensors: Location, Status
# 3. Sensors' values:
# >Location -> {A, B}, Status -> {Dirty, Clean}
# 4. List the actions: Suck, Right, Left
# 5. Agent function: **perception --> action**
# > [A, Clean] --> Right <br>
# > [A, Dirty] --> Suck<br>
# > [B, Clean] --> Left<br>
# > [B, Dirty] --> Suck<br>

# %% [markdown]
# # Simple reflex agent

# %%
def simple_reflex_agent(percept):
    print('Perception Received: '+ str(percept))
    location = percept[0]
    status = percept[1]
    if status =='Dirty':
        action = 'Suck'
    elif location == 'A':
        action = 'Right'
    elif location =='B':
        action = 'Left'
    return action

# %%
import random
Location = random.choice(['A','B'])
Condition = random.choice(['Clean','Dirty'])

while True:
    action= simple_reflex_agent((Location,Condition))
    print('Action Performed: '+ action)
    cmd = input('Get Perception (yes/no): ')
    if(cmd == 'no' or cmd != 'yes'): break
    if action == 'Right':
        Location = 'B'
        Condition = random.choice(['Clean','Dirty'])
    elif action== 'Left':
        Location = 'A'
        Condition = random.choice(['Clean','Dirty'])
    else:
        Condition = 'Clean'
# Out:
# Perception Received: ('B', 'Dirty')
# Action Performed: Suck
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Clean')
# Action Performed: Left
# Get Perception (yes/no): yes
# Perception Received: ('A', 'Clean')
# Action Performed: Right
# Get Perception (yes/no): yes
# Perception Received: ('B', 'Clean')
# Action Performed: Left

# %% [markdown]
# # Model based agent

# %%
model = {'A':'Unknown', 'B':'Unknown'}
world_state = 'Bad'
action = 'Unknown'

def update_state(action, percept, model):
    location = percept[0]
    status = percept[1]
    model[location] = status #udate the model based on current perception
    print('Perception: '+str(percept))
    print('Model before action: '+str(model))
    global world_state
    #udate the model based on action
    if action == 'Suck':
        model[location]='Clean'
    # model checking to update world state
    if model['A']=='Clean' and model['B']=='Clean':
        world_state = 'Good'
    else:
        world_state = 'Bad'
    return world_state

def model_based_reflex_agent(percept):
    location = percept[0]
    status = percept[1]
    global world_state,action,model
    if world_state == 'Good':
        action = 'Pause'
        return action
    elif status == 'Dirty':
        action = 'Suck'
    elif location == 'A':
        action = 'Right'
    elif location == 'B':
        action = 'Left'
    world_state = update_state(action, percept, model)
    print('Action Performed: '+ action)
    print('Model after action: '+str(model))
    print('State: '+str(world_state))
    return action

# %%
import random
Location = random.choice(['A','B'])
Condition= 'Dirty'
while True:
    print('*****')
    action = model_based_reflex_agent((Location,Condition))
    if action == 'Right':
        Location = 'B'
        Condition = 'Dirty'
    elif action == 'Left':
        Location = 'A'
        Condition = 'Dirty'
    elif action == 'Suck':
        Condition = 'Clean'
    elif action == 'Pause':
        cmd = input('Stopped. Do restart? (yes/no): ')
        if(cmd == 'no' or cmd != 'yes'): break
        Location = random.choice(['A','B'])
        Condition = random.choice(['Clean','Dirty'])
        model = {'A':'Unknown', 'B':'Unknown'}
        world_state = 'Bad'
        action = 'Unknown'
# Out:
# *****
# Perception: ('A', 'Dirty')
# Model before action: {'A': 'Dirty', 'B': 'Unknown'}
# Action Performed: Suck
# Model after action: {'A': 'Clean', 'B': 'Unknown'}
# State: Bad
# *****
# Perception: ('A', 'Clean')
# Model before action: {'A': 'Clean', 'B': 'Unknown'}
# Action Performed: Right
# Model after action: {'A': 'Clean', 'B': 'Unknown'}
# State: Bad
# *****
# Perception: ('B', 'Dirty')
# Model before action: {'A': 'Clean', 'B': 'Dirty'}
# Action Performed: Suck
# Model after action: {'A': 'Clean', 'B': 'Clean'}
# State: Good
# *****

# %% [markdown]
# # **Exercise 1**

# %% [markdown]
# Implement Modle Based agent for the following scenario
#
# Suppose that you have to design a vacuum-cleaner robot, which
# will operate in an apartment with 3 rooms in a row. It has the
# following allowed actions with the associated costs: move left, moveright , and clean. Initially,all the rooms are dirty and the robot randomly can start cleaning either from the 1st room or the last room. The goal of the agent is to keep all the rooms clean.

# %%
#write your code.

# %%
# Model-based reflex agent with 3 rooms
model = {'A':'Unknown', 'B':'Unknown', 'C':'Unknown'}
world_state = 'Bad'
action = 'Unknown'

def update_state(action, percept, model):
    location = percept[0]
    status = percept[1]
    model[location] = status
    
    print('Perception: '+str(percept))
    print('Model before action: '+str(model))
    
    global world_state
    if action == 'Suck':
        model[location] = 'Clean'
    if model['A'] == 'Clean' and model['B'] == 'Clean' and model['C'] == 'Clean':
        world_state = 'Good'
    else:
        world_state = 'Bad'
    return world_state

def model_based_reflex_agent(percept):
    location = percept[0]
    status = percept[1]
    global world_state, action, model
    if world_state == 'Good':
        action = 'Pause'
        return action
    if status == 'Dirty':
        action = 'Suck'
    elif location == 'A':
        action = 'Right'
    elif location == 'B':
        if model['C'] == 'Unknown' or model['C'] == 'Dirty':
            action = 'Right'
        else:
            action = 'Left'
    elif location == 'C':
        action = 'Left'
    
    world_state = update_state(action, percept, model)
    print('Action Performed: '+ action)
    print('Model after action: '+str(model))
    print('State: '+str(world_state))
    return action

# %%
import random
Location = random.choice(['A', 'C'])
Condition = 'Dirty'

while True:
    print('---' * 5)
    action = model_based_reflex_agent((Location, Condition))
    
    if action == 'Right':
        if Location == 'A':
            Location = 'B'
        elif Location == 'B':
            Location = 'C'
        Condition = 'Dirty'
    elif action == 'Left':
        if Location == 'C':
            Location = 'B'
        elif Location == 'B':
            Location = 'A'
        Condition = 'Dirty'
    elif action == 'Suck':
        Condition = 'Clean'
    elif action == 'Pause':
        cmd = input('Stopped. Do restart? (yes/no): ')
        if(cmd.lower() == 'no' or cmd.lower() != 'yes'):
            print("Exiting Simulation.")
            break
        Location = random.choice(['A', 'C'])
        Condition = 'Dirty'
        model = {'A':'Unknown', 'B':'Unknown', 'C':'Unknown'}
        world_state = 'Bad'
        action = 'Unknown'
# Out:
# ---------------
# ---------------
# Perception: ('A', 'Dirty')
# Model before action: {'A': 'Dirty', 'B': 'Unknown', 'C': 'Unknown'}
# Action Performed: Suck
# Model after action: {'A': 'Clean', 'B': 'Unknown', 'C': 'Unknown'}
# State: Bad
# ---------------
# Perception: ('A', 'Clean')
# Model before action: {'A': 'Clean', 'B': 'Unknown', 'C': 'Unknown'}
# Action Performed: Right
# Model after action: {'A': 'Clean', 'B': 'Unknown', 'C': 'Unknown'}
# State: Bad
# ---------------
# Perception: ('B', 'Dirty')
# Model before action: {'A': 'Clean', 'B': 'Dirty', 'C': 'Unknown'}
# Action Performed: Suck
# Model after action: {'A': 'Clean', 'B': 'Clean', 'C': 'Unknown'}
# State: Bad
# ---------------
# Perception: ('B', 'Clean')
# Model before action: {'A': 'Clean', 'B': 'Clean', 'C': 'Unknown'}
# Action Performed: Right
# Model after action: {'A': 'Clean', 'B': 'Clean', 'C': 'Unknown'}
# State: Bad
# ---------------
# Perception: ('C', 'Dirty')
# Model before action: {'A': 'Clean', 'B': 'Clean', 'C': 'Dirty'}
# Action Performed: Suck
# Model after action: {'A': 'Clean', 'B': 'Clean', 'C': 'Clean'}
# State: Good
# ---------------
# Exiting Simulation.
